# %% [markdown]
# ## Introduction
#
# Following the lecture taught on the processes of wrangling data and knowing that real world data almost never comes clean, I have applied all the steps listed in the wrangle report
# #in order to come up with the following result below
#
# 1. A maximum of 19 tweets were created over time on a daily and this kept on reducing by the day and further decreased in 2017. This may be as a result of reducing popularuty of this particular tweet types
#
# A total of 581 tweets were recorded over the 2016 and 2017 time period, which an averge of 3 tweets and the lowest number of tweets recorded in a data was 1.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
df = pd.read_csv('twitter_archive_master.csv')
df
# Out:
#       Unnamed: 0            tweet_id                timestamp_x  \
# 0              0  892420643555336193  2017-08-01 16:23:56+00:00
# 1              1  892177421306343426  2017-08-01 00:17:27+00:00
# 2              2  891815181378084864  2017-07-31 00:18:03+00:00
# 3              3  891689557279858688  2017-07-30 15:58:51+00:00
# 4              4  891327558926688256  2017-07-29 16:00:24+00:00
# ...          ...                 ...                        ...
# 1989        1989  666049248165822465  2015-11-16 00:24:50+00:00
# 1990        1990  666044226329800704  2015-11-16 00:04:52+00:00
# 1991        1991  666033412701032449  2015-11-15 23:21:54+00:00
# 1992        1992  666029285002620928  2015-11-15 23:05:30+00:00
# 1993        1993  666020888022790149  2015-11-15 22:32:08+00:00
#
#                                                source_x  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# ...

# %%
top_names = df.name_x.value_counts().nlargest()
top_names
# Out:
# a          55
# Charlie    11
# Lucy       10
# Cooper     10
# Oliver     10
# Name: name_x, dtype: int64

# %%
top_names.plot(kind='bar')
plt.xticks(rotation=60)
plt.show()
